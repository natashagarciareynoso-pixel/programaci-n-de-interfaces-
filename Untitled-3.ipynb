# %%
#Par o impar
#Flores Maria

#par o impar
#Flores Maria
 
def es_par(numero)
    if numero % 2 == 0:
        return "Es par"
 
 else:
    return "Es impar"

print(es_par(8))

# %%
#Promedio}
#Maria jose

def promedio(a, b, c):
    return (a + b + c) / 3

print(Promedio (5, 5, 6))
