# %%
print("operador matematicos")
print("realiza la suma 4 + 16 =" , 4 + 16)
print("realiza la suma 22 + 55 =" , 22 + 55 )
print("realiza la suma 44 + 34 =" , 44 + 34)
print("realiza la suma 99 + 15 =" , 99 + 15)
print("realiza la suma 81 + 4 =" , 81 + 4)
print("realiza la suma 5 + 1 =" , 5 + 1)
print("realiza la suma 9 + 24 =" , 9 + 24 )
print("realiza la suma 17 + 23 =" , 17 + 23)
print("realiza la suma 69 + 18 =" , 69 + 18)
print("realiza la suma 44 + 99 =" , 44 + 99)
# Out:
# operador matematicos
# realiza la suma 4 + 16 = 20
# realiza la suma 22 + 55 = 77
# realiza la suma 44 + 34 = 78
# realiza la suma 99 + 15 = 114
# realiza la suma 81 + 4 = 85
# realiza la suma 5 + 1 = 6
# realiza la suma 9 + 24 = 33
# realiza la suma 17 + 23 = 40
# realiza la suma 69 + 18 = 87
# realiza la suma 44 + 99 = 143

# %%
print("realiza la resta 50 - 14 =" , 50 - 14)
print("realiza la resta 99 - 77 =" , 99 - 77)
print("realiza la resta 88 - 41 =" , 88 - 41)
print("realiza la resta 76 - 33 =" , 76 - 33)
print("realiza la resta 52 - 16 =" , 52 - 16)
print("realiza la resta 14 - 11 =" , 14 - 11)
print("realiza la resta 22 - 13 =" , 22 - 13)
print("realiza la resta 111 - 33 =" , 111 - 33)
print("realiza la resta 999 - 666 =" , 999 - 666)
print("realiza la resta 55 - 44 =" , 55 - 44)
# Out:
# realiza la resta 50 - 14 = 36
# realiza la resta 99 - 77 = 22
# realiza la resta 88 - 41 = 47
# realiza la resta 76 - 33 = 43
# realiza la resta 52 - 16 = 36
# realiza la resta 14 - 11 = 3
# realiza la resta 22 - 13 = 9
# realiza la resta 111 - 33 = 78
# realiza la resta 999 - 666 = 333
# realiza la resta 55 - 44 = 11

# %%
print("realiza la multiplicacion 48 * 5 =" , 48 * 5)
print("realiza la multiplicacion 55 * 85 =" , 55 * 85)
print("realiza la multiplicacion 88 * 44 =" , 88 * 44)
print("realiza la multiplicacion 899 * 78 =" , )
print("realiza la multiplicacion 99 * 23 =" , 99 * 23)
print("realiza la multiplicacion 77 * 11 =" , 77 * 11)
print("realiza la multiplicacion 45 * 21 =" , 45 * 21)
print("realiza la multiplicacion 26 * 32 =" , 26 * 32)
print("realiza la multiplicacion 12 * 12 =" , 12 * 12)
print("realiza la multiplicacion 45 * 45 =" , 45 *45)
# Out:
# realiza la multiplicacion 48 * 5 = 240
# realiza la multiplicacion 55 * 85 = 4675
# realiza la multiplicacion 88 * 44 = 3872
# realiza la multiplicacion 899 * 78 =
# realiza la multiplicacion 99 * 23 = 2277
# realiza la multiplicacion 77 * 11 = 847
# realiza la multiplicacion 45 * 21 = 945
# realiza la multiplicacion 26 * 32 = 832
# realiza la multiplicacion 12 * 12 = 144
# realiza la multiplicacion 45 * 45 = 2025

# %%
print("realiza la divicion 99 / 8 =" , 99 / 8)
print("realiza la divicion 22 / 3 =" , 22 / 3)
print("realiza la divicion 88 / 5 =" , 88 / 5)
print("realiza la divicion 77 / 3 =" , 77 / 3)
print("realiza la divicion 888 / 78 =" , 888 / 78)
print("realiza la divicion 66 / 6 =" , 66 / 6)
print("realiza la divicion 34 / 23 =" , 34 / 23)
print("realiza la divicion 15 / 2 =" , 15 / 2)
print("realiza la divicion 55 / 15 =" , 55 / 15)
print("realiza la divicion 77 / 13 =" , 77 / 13)
# Out:
# realiza la divicion 99 / 8 = 12.375
# realiza la divicion 22 / 3 = 7.333333333333333
# realiza la divicion 88 / 5 = 17.6
# realiza la divicion 77 / 3 = 25.666666666666668
# realiza la divicion 888 / 78 = 11.384615384615385
# realiza la divicion 66 / 6 = 11.0
# realiza la divicion 34 / 23 = 1.4782608695652173
# realiza la divicion 15 / 2 = 7.5
# realiza la divicion 55 / 15 = 3.6666666666666665
# realiza la divicion 77 / 13 = 5.923076923076923
