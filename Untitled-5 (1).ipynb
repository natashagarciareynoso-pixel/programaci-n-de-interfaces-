# %%
1 # sorteo
2 # natasha jocelyn
3
4 original = [45,12 78,3,56]
5 nueve = sorted(original)
6 desc = sorted(original,reverse-True) 
7 print("original:",original)
8 print("orden ascendente;",nueva)
9 print("orden descendente",desc)
10 print("ganador sorteo",)
11 print(f"Primer Ganador {desc[1]}")
12 print(f"Segundo Ganador {desc[2]}")

# %%
 prom1 = int(input("agrega tu primer promedio:\n> "))
    prom2 = int(input("agrega tu segundo promedio:\n> "))
    prom3 = int(input("agrega tu tercer promedio:\n> "))
    prom4 = int(input("agrega tu cuarto promedio:\n> "))
    prom5 = int(input("agrega tu quinto promedio:\n> "))

    if (prom1 > 10) or (prom2 > 10) or (prom3 > 10) or (prom4 > 10) or (prom5 > 10):
        print("Los promedios ingresados no pueden ser mayor a 10")
        exit()

    prom_suma = prom1 + prom2 + prom3 + prom4 + prom5

    total = prom_suma / 5

    print(f"Promedio total: {total}" )

except ValueError:
    print("Por favor, agrega un numero valido")
# Out:
#   Cell In[2], line 2
#     prom2 = int(input("agrega tu segundo promedio:\n> "))
#     ^
# IndentationError: unexpected indent
